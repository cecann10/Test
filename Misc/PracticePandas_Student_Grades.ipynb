# %%
import numpy as np
import pandas as pd

# %%
# import the csv file with raw data for grades of students

df_grades = pd.read_csv("https://people.sc.fsu.edu/~jburkardt/data/csv/grades.csv")

# %%
# Creates new 'clean' names for columns that don't have quotation marks surrounding them

columns_grades = ['LastName', 'FirstName','SSN','Test1', 
                  'Test2','Test3', 'Test4','Final','Grade']

df_grades.columns = columns_grades

# %%
df_grades.head(6)
# Out:
#   LastName         FirstName                   SSN  Test1  Test2  Test3  \
# 0  Alfalfa        "Aloysius"         "123-45-6789"   40.0   90.0  100.0
# 1   Alfred      "University"         "123-12-1234"   41.0   97.0   96.0
# 2    Gerty          "Gramma"         "567-89-0123"   41.0   80.0   60.0
# 3  Android        "Electric"         "087-65-4321"   42.0   23.0   36.0
# 4  Bumpkin            "Fred"         "456-78-9012"   43.0   78.0   88.0
# 5   Rubble           "Betty"         "234-56-7890"   44.0   90.0   80.0
#
#    Test4     Final    Grade
# 0   83.0      49.0     "D-"
# 1   97.0      48.0     "D+"
# 2   40.0      44.0      "C"
# 3   45.0      47.0     "B-"
# 4   77.0      45.0     "A-"
# 5   90.0      46.0     "C-"

# %%
# Cleaning FirstName column to remove spaces and quotations

df_grades['FirstName'] = df_grades.FirstName.str.strip(' "')

# %%
df_grades.FirstName.unique()
# Out:
# array(['Aloysius', 'University', 'Gramma', 'Electric', 'Fred', 'Betty',
#        'Cecil', 'Bif', 'Andrew', 'Jim', 'Art', 'Ima', 'Benny', 'Boy',
#        'Harvey'], dtype=object)

# %%
# Cleaning SSN column to remove spaces and quotations

df_grades['SSN'] = df_grades.SSN.str.strip(' "')

# %%
# Cleaning Grade column to remove spaces and quotations

df_grades['Grade'] = df_grades.Grade.str.strip(' "')

# %%
df_grades.head()
# Out:
#   LastName   FirstName          SSN  Test1  Test2  Test3  Test4     Final  \
# 0  Alfalfa    Aloysius  123-45-6789   40.0   90.0  100.0   83.0      49.0
# 1   Alfred  University  123-12-1234   41.0   97.0   96.0   97.0      48.0
# 2    Gerty      Gramma  567-89-0123   41.0   80.0   60.0   40.0      44.0
# 3  Android    Electric  087-65-4321   42.0   23.0   36.0   45.0      47.0
# 4  Bumpkin        Fred  456-78-9012   43.0   78.0   88.0   77.0      45.0
#
#   Grade
# 0    D-
# 1    D+
# 2     C
# 3    B-
# 4    A-

# %%
# Cleaning Test1 column to remove spaces

df_grades['Test1'] = df_grades.Test1.str.strip('')

# %%
df_grades.loc[8,'Test1'] = 49.0

# %%
# Cleaning Test1 column so values are floats instead of strings

df_grades['Test1'] = pd.to_numeric(df_grades.Test1)

# %%
# Creating new column to just be the 'plus' or 'minus' of the final grade
df_grades['ScaleGrade'] = df_grades.Grade.str[1]

# %%
# Creating new column to just be the alphabetical final grade

df_grades.insert(9, 'LetterGrade', df_grades.Grade.str[0])

# %%
# Deleting now redundant Grade column

del df_grades['Grade']

# %%
df_grades.head(6)
# Out:
#   LastName   FirstName          SSN  Test1  Test2  Test3  Test4     Final  \
# 0  Alfalfa    Aloysius  123-45-6789   40.0   90.0  100.0   83.0      49.0
# 1   Alfred  University  123-12-1234   41.0   97.0   96.0   97.0      48.0
# 2    Gerty      Gramma  567-89-0123   41.0   80.0   60.0   40.0      44.0
# 3  Android    Electric  087-65-4321   42.0   23.0   36.0   45.0      47.0
# 4  Bumpkin        Fred  456-78-9012   43.0   78.0   88.0   77.0      45.0
# 5   Rubble       Betty  234-56-7890   44.0   90.0   80.0   90.0      46.0
#
#   LetterGrade ScaleGrade
# 0           D          -
# 1           D          +
# 2           C        NaN
# 3           B          -
# 4           A          -
# 5           C          -

# %%
df_grades.groupby("LetterGrade").mean().head(1)
# Out:
#              Test1  Test2  Test3  Test4
# LetterGrade
# A             45.5   39.5   92.5   86.5

# %%
df_grades.iloc[8,7] = ""

# %%
df_grades.Final = pd.to_numeric(df_grades.Final)

# %%
df_grades
# Out:
#      LastName   FirstName          SSN  Test1  Test2  Test3  Test4  Final  \
# 0     Alfalfa    Aloysius  123-45-6789   40.0   90.0  100.0   83.0   49.0
# 1      Alfred  University  123-12-1234   41.0   97.0   96.0   97.0   48.0
# 2       Gerty      Gramma  567-89-0123   41.0   80.0   60.0   40.0   44.0
# 3     Android    Electric  087-65-4321   42.0   23.0   36.0   45.0   47.0
# 4     Bumpkin        Fred  456-78-9012   43.0   78.0   88.0   77.0   45.0
# 5      Rubble       Betty  234-56-7890   44.0   90.0   80.0   90.0   46.0
# 6      Noshow       Cecil  345-67-8901   45.0   11.0   -1.0    4.0   43.0
# 7        Buff         Bif  632-79-9939   46.0   20.0   30.0   40.0   50.0
# 8     Airpump      Andrew  223-45-6789   49.0   90.0  100.0   83.0    NaN
# 9      Backus         Jim  143-12-1234   48.0    1.0   97.0   96.0   97.0
# 10  Carnivore         Art  565-89-0123   44.0    1.0   80.0   60.0   40.0
# 11      Dandy         Jim  087-75-4321   47.0    1.0   23.0   36.0   45.0
# 12   Elephant         Ima  456-71-9012   45.0    1.0   78.0   88.0   77.0
# 13   Franklin       Benny  234-56-2890   50.0    1.0   90.0   80.0   90.0
# 14     George         Boy  345-67-3901   40.0    1.0   11.0   -1.0    4.0
# 15  Heffalump      Harvey  632-79-9439   30.0    1.0   20.0   30.0   40.0
#
#    LetterGrade ScaleGrade
# 0            D          -
# 1            D          +
# 2            C        NaN
# 3            B          -
# 4            A          -
# 5            C          -
# 6            F        NaN
# 7            B          +
# 8          NaN        NaN
# 9            A          +
# 10           D          +
# 11           C          +
# 12           B          -
# 13           B          -
# 14           B        NaN
# 15           C        NaN

# %%
df_grades.iloc[8,3]
# Out:
# 49.0

# %%
df_grades.iloc[8,3] = 49.0

# %%
df_grades.iloc[8,3]
# Out:
# 49.0

# %%
df_grades.sort_values('Final', ascending = False).Final.head(2).mean()
# Out:
# 93.5

# %%
df_grades.iloc[8,7] = df_grades.sort_values('Final', ascending = False).Final.head(2).mean()

# %%
df_grades.iloc[8,7]
# Out:
# 93.5

# %%
df_grades.loc[8,"Test1":"Final"].mean()
# Out:
# 83.1

# %%
# Creating function to create final grade based on series of scores

def grade(scores_list):
    grade_num = scores_list.mean()
    if grade_num >= 90.0:
        return "A"
    if grade_num < 90 and grade_num >= 80:
        return "B"
    if grade_num < 80 and grade_num >= 70:
        return "C"
    if grade_num < 70 and grade_num >= 60:
        return "D"
    if grade_num < 60:
        return "F"

# %%
grade(df_grades.loc[8,"Test1":"Final"])
# Out:
# 'B'

# %%
# Adding grade to spot in df where grade was missing

df_grades.iloc[8,8] = grade(df_grades.loc[8,"Test1":"Final"])

# %%
df_grades.sort_values(['LetterGrade','ScaleGrade'])
# Out:
#      LastName   FirstName          SSN  Test1  Test2  Test3  Test4  Final  \
# 9      Backus         Jim  143-12-1234   48.0    1.0   97.0   96.0   97.0
# 4     Bumpkin        Fred  456-78-9012   43.0   78.0   88.0   77.0   45.0
# 7        Buff         Bif  632-79-9939   46.0   20.0   30.0   40.0   50.0
# 3     Android    Electric  087-65-4321   42.0   23.0   36.0   45.0   47.0
# 12   Elephant         Ima  456-71-9012   45.0    1.0   78.0   88.0   77.0
# 13   Franklin       Benny  234-56-2890   50.0    1.0   90.0   80.0   90.0
# 8     Airpump      Andrew  223-45-6789   49.0   90.0  100.0   83.0   93.5
# 14     George         Boy  345-67-3901   40.0    1.0   11.0   -1.0    4.0
# 11      Dandy         Jim  087-75-4321   47.0    1.0   23.0   36.0   45.0
# 5      Rubble       Betty  234-56-7890   44.0   90.0   80.0   90.0   46.0
# 2       Gerty      Gramma  567-89-0123   41.0   80.0   60.0   40.0   44.0
# 15  Heffalump      Harvey  632-79-9439   30.0    1.0   20.0   30.0   40.0
# 1      Alfred  University  123-12-1234   41.0   97.0   96.0   97.0   48.0
# 10  Carnivore         Art  565-89-0123   44.0    1.0   80.0   60.0   40.0
# 0     Alfalfa    Aloysius  123-45-6789   40.0   90.0  100.0   83.0   49.0
# 6      Noshow       Cecil  345-67-8901   45.0   11.0   -1.0    4.0   43.0
#
#    LetterGrade ScaleGrade
# 9            A          +
# 4            A          -
# 7            B          +
# 3            B          -
# 12           B          -
# 13           B          -
# 8            B        NaN
# 14           B        NaN
# 11           C          +
# 5            C          -
# 2            C        NaN
# 15           C        NaN
# 1            D          +
# 10           D          +
# 0            D          -
# 6            F        NaN

# %%
df_grades.ScaleGrade.unique()
# Out:
# array(['-', '+', nan], dtype=object)

# %%
df_grades.insert(9,"ScaleGrade_Rank", 
                 [1 if scale == '-' 
                  else 3 if scale == '+' 
                  else 2 for scale in df_grades.ScaleGrade])

# %%
df_grades.sort_values(['LetterGrade','ScaleGrade_Rank'])
# Out:
#      LastName   FirstName          SSN  Test1  Test2  Test3  Test4  Final  \
# 4     Bumpkin        Fred  456-78-9012   43.0   78.0   88.0   77.0   45.0
# 9      Backus         Jim  143-12-1234   48.0    1.0   97.0   96.0   97.0
# 3     Android    Electric  087-65-4321   42.0   23.0   36.0   45.0   47.0
# 12   Elephant         Ima  456-71-9012   45.0    1.0   78.0   88.0   77.0
# 13   Franklin       Benny  234-56-2890   50.0    1.0   90.0   80.0   90.0
# 8     Airpump      Andrew  223-45-6789   49.0   90.0  100.0   83.0   93.5
# 14     George         Boy  345-67-3901   40.0    1.0   11.0   -1.0    4.0
# 7        Buff         Bif  632-79-9939   46.0   20.0   30.0   40.0   50.0
# 5      Rubble       Betty  234-56-7890   44.0   90.0   80.0   90.0   46.0
# 2       Gerty      Gramma  567-89-0123   41.0   80.0   60.0   40.0   44.0
# 15  Heffalump      Harvey  632-79-9439   30.0    1.0   20.0   30.0   40.0
# 11      Dandy         Jim  087-75-4321   47.0    1.0   23.0   36.0   45.0
# 0     Alfalfa    Aloysius  123-45-6789   40.0   90.0  100.0   83.0   49.0
# 1      Alfred  University  123-12-1234   41.0   97.0   96.0   97.0   48.0
# 10  Carnivore         Art  565-89-0123   44.0    1.0   80.0   60.0   40.0
# 6      Noshow       Cecil  345-67-8901   45.0   11.0   -1.0    4.0   43.0
#
#    LetterGrade  ScaleGrade_Rank ScaleGrade
# 4            A                1          -
# 9            A                3          +
# 3            B                1          -
# 12           B                1          -
# 13           B                1          -
# 8            B                2        NaN
# 14           B                2        NaN
# 7            B                3          +
# 5            C                1          -
# 2            C                2        NaN
# 15           C                2        NaN
# 11           C                3          +
# 0            D                1          -
# 1            D                3          +
# 10           D                3          +
# 6            F                2        NaN

# %%
# Create column for what the final number would be to result in the final grade
# Takes in all grades and outputs mean

df_grades['NumberGrade'] = [
    round(df_grades.loc[index,"Test1":"Final"].mean(),2)
    for index in df_grades.index]

# %%
# Cleans up Test2, Test3, Test4, and Final columns
# Turns any numbers listed under 30 as NaN since unlikely correct as grade
# Will allow ease in calculating final grades

df_grades['Test2'] = [np.nan if x<30 else x for x in df_grades.Test2]
df_grades['Test3'] = [np.nan if x<30 else x for x in df_grades.Test3]
df_grades['Test4'] = [np.nan if x<30 else x for x in df_grades.Test4]
df_grades['Final'] = [np.nan if x<30 else x for x in df_grades.Final]

# %%
df_grades2 = (df_grades.loc[:,"LastName":"Final"]).join((df_grades.loc[:,"NumberGrade"]))

df_grades = df_grades2.join((df_grades.loc[:,"LetterGrade":"ScaleGrade"]))

df_grades
# Out:
#      LastName   FirstName          SSN  Test1  Test2  Test3  Test4  Final  \
# 0     Alfalfa    Aloysius  123-45-6789   40.0   90.0  100.0   83.0   49.0
# 1      Alfred  University  123-12-1234   41.0   97.0   96.0   97.0   48.0
# 2       Gerty      Gramma  567-89-0123   41.0   80.0   60.0   40.0   44.0
# 3     Android    Electric  087-65-4321   42.0    NaN   36.0   45.0   47.0
# 4     Bumpkin        Fred  456-78-9012   43.0   78.0   88.0   77.0   45.0
# 5      Rubble       Betty  234-56-7890   44.0   90.0   80.0   90.0   46.0
# 6      Noshow       Cecil  345-67-8901   45.0    NaN    NaN    NaN   43.0
# 7        Buff         Bif  632-79-9939   46.0    NaN   30.0   40.0   50.0
# 8     Airpump      Andrew  223-45-6789   49.0   90.0  100.0   83.0   93.5
# 9      Backus         Jim  143-12-1234   48.0    NaN   97.0   96.0   97.0
# 10  Carnivore         Art  565-89-0123   44.0    NaN   80.0   60.0   40.0
# 11      Dandy         Jim  087-75-4321   47.0    NaN    NaN   36.0   45.0
# 12   Elephant         Ima  456-71-9012   45.0    NaN   78.0   88.0   77.0
# 13   Franklin       Benny  234-56-2890   50.0    NaN   90.0   80.0   90.0
# 14     George         Boy  345-67-3901   40.0    NaN    NaN    NaN    NaN
# 15  Heffalump      Harvey  632-79-9439   30.0    NaN    NaN   30.0   40.0
#
#     NumberGrade LetterGrade  ScaleGrade_Rank ScaleGrade
# 0          72.4           D                1          -
# 1          75.8           D                3          +
# 2          53.0           C                2        NaN
# 3          38.6           B                1          -
# 4          66.2           A                1          -
# 5          70.0           C                1          -
# 6          20.4           F                2        NaN
# 7          37.2           B                3          +
# 8          83.1           B                2        NaN
# 9          67.8           A                3          +
# 10         45.0           D                3          +
# 11         30.4           C                3          +
# 12         57.8           B                1          -
# 13         62.2           B                1          -
# 14         11.0           B                2        NaN
# 15         24.2           C                2        NaN

# %%
# Final clean dataframe for the grades

df_grades
# Out:
#      LastName   FirstName          SSN  Test1  Test2  Test3  Test4  Final  \
# 0     Alfalfa    Aloysius  123-45-6789   40.0   90.0  100.0   83.0   49.0
# 1      Alfred  University  123-12-1234   41.0   97.0   96.0   97.0   48.0
# 2       Gerty      Gramma  567-89-0123   41.0   80.0   60.0   40.0   44.0
# 3     Android    Electric  087-65-4321   42.0    NaN   36.0   45.0   47.0
# 4     Bumpkin        Fred  456-78-9012   43.0   78.0   88.0   77.0   45.0
# 5      Rubble       Betty  234-56-7890   44.0   90.0   80.0   90.0   46.0
# 6      Noshow       Cecil  345-67-8901   45.0    NaN    NaN    NaN   43.0
# 7        Buff         Bif  632-79-9939   46.0    NaN   30.0   40.0   50.0
# 8     Airpump      Andrew  223-45-6789   49.0   90.0  100.0   83.0   93.5
# 9      Backus         Jim  143-12-1234   48.0    NaN   97.0   96.0   97.0
# 10  Carnivore         Art  565-89-0123   44.0    NaN   80.0   60.0   40.0
# 11      Dandy         Jim  087-75-4321   47.0    NaN    NaN   36.0   45.0
# 12   Elephant         Ima  456-71-9012   45.0    NaN   78.0   88.0   77.0
# 13   Franklin       Benny  234-56-2890   50.0    NaN   90.0   80.0   90.0
# 14     George         Boy  345-67-3901   40.0    NaN    NaN    NaN    NaN
# 15  Heffalump      Harvey  632-79-9439   30.0    NaN    NaN   30.0   40.0
#
#     NumberGrade LetterGrade  ScaleGrade_Rank ScaleGrade
# 0          72.4           D                1          -
# 1          75.8           D                3          +
# 2          53.0           C                2        NaN
# 3          38.6           B                1          -
# 4          66.2           A                1          -
# 5          70.0           C                1          -
# 6          20.4           F                2        NaN
# 7          37.2           B                3          +
# 8          83.1           B                2        NaN
# 9          67.8           A                3          +
# 10         45.0           D                3          +
# 11         30.4           C                3          +
# 12         57.8           B                1          -
# 13         62.2           B                1          -
# 14         11.0           B                2        NaN
# 15         24.2           C                2        NaN

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_grades.NumberGrade
# Out:
# 0     72.4
# 1     75.8
# 2     53.0
# 3     38.6
# 4     66.2
# 5     70.0
# 6     20.4
# 7     37.2
# 8     83.1
# 9     67.8
# 10    45.0
# 11    30.4
# 12    57.8
# 13    62.2
# 14    11.0
# 15    24.2
# Name: NumberGrade, dtype: float64

# %%
class_num_grade = df_grades.NumberGrade
class_alpha_grade = df_grades.LetterGrade

# %%
test1_score = df_grades.Test1
test2_score = df_grades.Test2
test3_score = df_grades.Test3
test4_score = df_grades.Test4
final_score = df_grades.Final

# %%
plt.figure(figsize=[15,5])
plt.suptitle('Final Score vs. Class Grades')

plt.subplot(1,2,1)
plt.title("Final Score")
plt.hist(final_score)
plt.xlabel("Final Score in %", family="serif")
plt.ylabel("Frequency", family='serif')

plt.subplot(1,2,2)
plt.title("Class Grade")
plt.hist(class_num_grade)
plt.xlabel("Class Grade in %", family="serif")
plt.ylabel("Frequency", family='serif');
# Out:
# /Users/celinaplaza/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/celinaplaza/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plt.figure(figsize=[15,15])

plt.suptitle('All Test Scores',fontsize = 16)

plt.subplot(2,2,1)
plt.hist(test1_score, color='orange')
plt.xlabel("% Scores", size=12)
plt.ylabel("Frequency", size=12)
plt.axis([0, 100, 0, 5])

plt.subplot(2,2,2)
plt.hist(test2_score, color='#eb4034')
plt.xlabel("% Scores", size=12)
plt.ylabel("Frequency", size=12)
plt.axis([0, 100, 0, 5])

plt.subplot(2,2,3)
plt.hist(test3_score, color='#e667e6')
plt.xlabel("% Scores", size=12)
plt.ylabel("Frequency", size=12)
plt.axis([0, 100, 0, 5])

plt.subplot(2,2,4)
plt.hist(test4_score, color='#8fe667')
plt.xlabel("% Scores", size=12)
plt.ylabel("Frequency", size=12)
plt.axis([0, 100, 0, 5]);

# %%
df_grades.loc[:,"Test1":"Final"].describe()
# Out:
#           Test1      Test2       Test3     Test4      Final
# count  16.00000   6.000000   12.000000  14.00000  15.000000
# mean   43.43750  87.500000   77.916667  67.50000  56.966667
# std     4.74649   7.148426   23.925864  24.50981  20.817632
# min    30.00000  78.000000   30.000000  30.00000  40.000000
# 25%    41.00000  82.500000   73.500000  41.25000  44.500000
# 50%    44.00000  90.000000   84.000000  78.50000  47.000000
# 75%    46.25000  90.000000   96.250000  86.75000  63.500000
# max    50.00000  97.000000  100.000000  97.00000  97.000000

# %%
df_grades.columns
# Out:
# Index(['LastName', 'FirstName', 'SSN', 'Test1', 'Test2', 'Test3', 'Test4',
#        'Final', 'NumberGrade', 'LetterGrade', 'ScaleGrade_Rank', 'ScaleGrade'],
#       dtype='object')

# %%
df_grades.loc[:,['SSN','Test1']][df_grades.LetterGrade=='A']
# Out:
#            SSN  Test1
# 4  456-78-9012   43.0
# 9  143-12-1234   48.0

# %%
df_grades.groupby('LetterGrade').mean()
# Out:
#                  Test1  Test2  Test3  Test4      Final  NumberGrade  \
# LetterGrade
# A            45.500000   78.0   92.5   86.5  71.000000    67.000000
# B            45.333333   90.0   66.8   67.2  71.500000    48.316667
# C            40.500000   85.0   70.0   49.0  43.750000    44.400000
# D            41.666667   93.5   92.0   80.0  45.666667    64.400000
# F            45.000000    NaN    NaN    NaN  43.000000    20.400000
#
#              ScaleGrade_Rank
# LetterGrade
# A                   2.000000
# B                   1.666667
# C                   2.000000
# D                   2.333333
# F                   2.000000

# %%
smpl_norm_numgrade = np.random.normal(df_grades.NumberGrade)

# %%
smpl_norm_numgrade
# Out:
# array([72.90077054, 77.11580269, 53.78906069, 37.82220918, 64.99294328,
#        69.60849046, 21.17524911, 37.97303926, 81.99971452, 67.03864647,
#        44.39898546, 29.14734116, 55.39827679, 61.89761651,  9.58387279,
#        24.47124891])

# %%
plt.hist(smpl_norm_numgrade);

# %%
from scipy import stats

# %%
# Testing t-tests -- here when using 'dropna() to take care of null

stats.ttest_ind(test1_score.dropna(), test4_score.dropna())
# Out:
# Ttest_indResult(statistic=-3.8545406093221524, pvalue=0.0006198017706734923)

# %%
# Testing t-test using nan_policy to address null values (preferred)

stats.ttest_ind(test1_score, test4_score, nan_policy='omit')
# Out:
# Ttest_indResult(statistic=-3.8545406093221524, pvalue=0.0006198017706734929)

# %%
# Finding p-value between Final scores and final number grade for class

tstat, pvalue = stats.ttest_ind(final_score, class_num_grade, nan_policy='omit')
print(tstat)
print(pvalue)
# Out:
# 0.7831343749817387
# 0.43989722321526237

# %%
# Finding p-value between first test scores and fourth test scores

tstat2, pvalue2 = stats.ttest_ind(test1_score, test4_score, nan_policy='omit')
print(tstat2)
print(pvalue2)
# Out:
# -3.8545406093221524
# 0.0006198017706734929
